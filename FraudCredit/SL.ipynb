# %% [markdown]
# # Pre

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
# Read the CSV data using pandas
df = pd.read_csv('/content/drive/MyDrive/Khoa_luan/Fraud_flip/fraud_detection_P3_2c_100/app-data/SB19_CCFDUBL_BAL_TEST_2C.csv')

# %%
X_test = df.drop('Class', axis=1)
Y_test = df['Class']

# %% [markdown]
# ### Thresehold

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score
best_threshold = None
# Calculate the area under the ROC curve
# Compute the FPR, TPR, and thresholds using the roc_curve function
fpr, tpr, thresholds = roc_curve(Y, y_pred)

# Calculate the F1 score for each threshold
f1_scores = [f1_score(Y, (y_pred >= threshold).astype(int)) for threshold in thresholds]

# Find the optimal threshold that maximizes the F1 score
optimal_threshold = thresholds[np.argmax(f1_scores)]

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.grid(True)
plt.show()

print("Optimal Threshold:", optimal_threshold)
# Out:
# Optimal Threshold: 0.45841533

# %% [markdown]
# # Dữ liệu bình thường

# %% [markdown]
# ## USER 1

# %%
import tensorflow as tf
from tensorflow import keras
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/Khoa_luan/FraudCredit/data-and-scratch/user1/fraud-detection')

# %%
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model.predict(X_test)
threshold = 0.45841533
y_pred = np.where(y_pred >= threshold, 1, 0)
# Out:
# 8/8 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9429824561403509
# Precision: 0.9316239316239316
# Recall: 0.956140350877193
# F1 Score: 0.9437229437229437

# %% [markdown]
# ## USER 2

# %%
import tensorflow as tf
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/Khoa_luan/FraudCredit/data-and-scratch/user2/fraud-detection')

# %%
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model.predict(X_test)
threshold = 0.45841533
y_pred = np.where(y_pred >= threshold, 1, 0)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9429824561403509
# Precision: 0.9316239316239316
# Recall: 0.956140350877193
# F1 Score: 0.9437229437229437

# %% [markdown]
# # Dữ liệu lật TH1

# %%
import tensorflow as tf
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/Khoa_luan/Fraud_flip/fraud_detection_P2_30/user4/fraud-detection')
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model.predict(X_test)
threshold = 0.45841533
y_pred = np.where(y_pred >= threshold, 1, 0)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.8859649122807017
# Precision: 0.8333333333333334
# Recall: 0.9649122807017544
# F1 Score: 0.8943089430894309

# %% [markdown]
# # Dữ liệu lật TH2

# %%
import tensorflow as tf
# Load the model from the .pb file
model = keras.models.load_model('/content/drive/MyDrive/Khoa_luan/Fraud_flip/fraud_detection_P3_2c_100/user4/fraud-detection')
from keras.optimizers import SGD
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss = 'binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
y_pred = model.predict(X_test)
threshold = 0.45841533
y_pred = np.where(y_pred >= threshold, 1, 0)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
# Out:
# 8/8 [==============================] - 0s 4ms/step

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.7894736842105263
# Precision: 0.7931034482758621
# Recall: 0.7931034482758621
# F1 Score: 0.7931034482758621
